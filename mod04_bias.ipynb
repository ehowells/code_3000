# %%
# import packages
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import shap
import matplotlib.pyplot as plt

# %%
seed = 2724

# %% [markdown]
# ### Import data

# %%
DF_PATH = "mod04_data/sample.csv"
df = pd.read_csv(DF_PATH)

# %% [markdown]
# ### Separate data by independent (X) and dependent (y) variables

# %%
X = df[["income", "education_years", "zipcode_score"]]
y = df["target"]

# %% [markdown]
# ### Split the data into a _training_ set (to build a model) and _test_ set (to validate a model)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=seed
)

# %% [markdown]
# ### Build a model on the training set

# %%
model = RandomForestRegressor(
    n_estimators=200,
    random_state=seed
)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=2724)

# %% [markdown]
# ### Use SHAP to explain the model on test data

# %%
explainer = shap.Explainer(model, X_train)
shap_values = explainer(X_test)
# Out:
#  98%|===================| 1477/1500 [00:50<00:00]

# %% [markdown]
# This will allow us to see which variables are most important to predicting the outcome.

# %%
shap.plots.bar(shap_values)

# %% [markdown]
# ### Import the `group` variable, which was **not** used in training this model.

# %%
X_test_with_group = X_test.copy()
X_test_with_group["group"] = df.loc[X_test.index, "group"]

# %% [markdown]
# ### Look at the difference in SHAP values between the two groups across the variables used in the model.

# %%
shap_df = pd.DataFrame(shap_values.values, columns=X_test.columns)
shap_df["group"] = X_test_with_group["group"].values

shap_df.groupby("group").mean()
# Out:
#          income  education_years  zipcode_score
# group
# 0      1.085462        -0.172202       5.865217
# 1      1.019984        -0.193786      -6.860764

# %% [markdown]
# ### Let's put `group` and `zipcode_score` in the same plot

# %%
def plot_shap(var):
    # Extract SHAP values for the feature
    shap_var = shap_values[:, var].values

    # Plot the values of each group using different colors
    plt.figure()
    plt.scatter(
        X_test[var],
        shap_var,
        c=X_test_with_group["group"]
    )
    plt.xlabel(var)
    plt.ylabel(f"SHAP value for var")
    plt.title("Proxy feature impact by group")
    plt.show()

plot_shap("zipcode_score")

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### What is a _SHAP_ (or Shapley) value?

# %% [markdown]
# A SHAP value shows how much a feature impacts a prediction. A negative SHAP value would indicate that the feature decreases the value of the prediction, while a positive one increases the prediction value.

# %% [markdown]
# ### Suppose you built this model and then it is peer reviewed by another entity. If the reviewer asks whether you used the variable `group` in your model, what would your answer be?

# %% [markdown]
# Group was not used in the model; it was trained on zipcode_score, income, and education_years. However, group was used indirectly through zipcode_score as a proxy variable, as the SHAP values indicate that zipcode_score is correlated with group.

# %% [markdown]
# ### If the reviewer asks whether the outcome of your model is correlated with `group`, what would your answer be?

# %% [markdown]
# Yes, the outcome of the model is correlated with group. The above plot shows that the impact of zipcode_score is different by group, suggesting that zipcode_score gives information about group membership. Therefore, because the model relies on zipcode_score, its predictions are likely correlated with group.

# %% [markdown]
# ### Construct a "proxy feature impact by group" plot for `income`. How is this plot different from the one for `zipcode_score`?

# %%
plot_shap('income')

# %% [markdown]
# This plot is different because both groups span the entire range of SHAP values for income, while the plot using zipcode_score shows a clear divide between SHAP values for the two groups. This means that income affects predictions similarly regardless of group, while zipcode_score produces very different predictions based on group.

# %% [markdown]
# ### If, instead, you were the **reviewer**, what other questions might you ask the person who built this model? Give at least two.

# %% [markdown]
# I would ask what the group variable represents (i.e. by what criteria are people grouped, since the answer would affect how seriously the bias should be taken) and if there are other features in the model that may act as proxy variables for group. The SHAP values show that group, despite being a prohibited variable, still has an impact on the model through zipcode_score, so it is important to identify any other variables that may be introducing bias to the model.
